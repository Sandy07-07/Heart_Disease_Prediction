# %% [markdown]
# # ***Importing the required libraries***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')
plt.style.use('Solarize_Light2')

# %% [markdown]
# # ***Importing the Dataset***

# %%
df = pd.read_csv('../input/heart-disease-dataset/heart.csv')

# %% [markdown]
# # ***Exploring and Cleaning the dataset***

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
# 5   0     2       1
# 6   3     1       0
# 7   1     3       0
# 8   0     3       0
# 9   2     2       0

# %%
df.tail(10)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1015   58    1   0       128   216    0        0      131      1      2.2
# 1016   65    1   3       138   282    1        0      174      0      1.4
# 1017   53    1   0       123   282    0        1       95      1      2.0
# 1018   41    1   0       110   172    0        0      158      0      0.0
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1015      1   3     3       0
# 1016      1   1     2       0
# 1017      1   2     3       0
# 1018      2   0     3       0
# 1019      2   0     2       1
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %% [markdown]
# # ***Checking for Null Values***

# %%
df.isnull().any()
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %% [markdown]
# # ***Checking for Duplicates***

# %%
df.duplicated().sum()
# Out:
# 723

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # ***Plotting histogram for the entire dataset***

# %%
fig = plt.figure(figsize = (15,15))
ax = fig.gca()
g = df.hist(ax=ax)

# %% [markdown]
# # ***Visualization to check if the dataset is balanced or not***

# %%
g = sns.countplot(x='target', data=df)
plt.xlabel('Target')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # ***Feature Selection***

# %% [markdown]
# ***Get correlation of all the features of the dataset***

# %%
# Selecting correlated features using Heatmap
corr_matrix = df.corr()
top_corr_features = corr_matrix.index

# Plotting the heatmap
plt.figure(figsize=(20,20))
sns.heatmap(data=df[top_corr_features].corr(), annot=True, cmap='RdYlGn')
# Out:
# <Axes: >

# %% [markdown]
# # ***Understanding the columns***

# %%
info = ["age","1: male, 0: female","chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic","resting blood pressure"," serum cholestoral in mg/dl","fasting blood sugar > 120 mg/dl","resting electrocardiographic results (values 0,1,2)"," maximum heart rate achieved","exercise induced angina","oldpeak = ST depression induced by exercise relative to rest","the slope of the peak exercise ST segment","number of major vessels (0-3) colored by flourosopy","thal: 3 = normal; 6 = fixed defect; 7 = reversable defect"]



for i in range(len(info)):
    print(df.columns[i]+":\t\t\t"+info[i])
# Out:
# age:			age
# sex:			1: male, 0: female
# cp:			chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic
# trestbps:			resting blood pressure
# chol:			 serum cholestoral in mg/dl
# fbs:			fasting blood sugar > 120 mg/dl
# restecg:			resting electrocardiographic results (values 0,1,2)
# thalach:			 maximum heart rate achieved
# exang:			exercise induced angina
# oldpeak:			oldpeak = ST depression induced by exercise relative to rest
# slope:			the slope of the peak exercise ST segment
# ca:			number of major vessels (0-3) colored by flourosopy
# thal:			thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %% [markdown]
# # ***Analyzing Target Variable***

# %%
df["target"].describe()
# Out:
# count    302.000000
# mean       0.543046
# std        0.498970
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: target, dtype: float64

# %%
df["target"].unique()
# Out:
# array([0, 1])

# %% [markdown]
# # ***Co-relation between columns***

# %%
print(df.corr()["target"].abs().sort_values(ascending=False))
# Out:
# target      1.000000
# exang       0.435601
# cp          0.432080
# oldpeak     0.429146
# thalach     0.419955
# ca          0.408992
# slope       0.343940
# thal        0.343101
# sex         0.283609
# age         0.221476
# trestbps    0.146269
# restecg     0.134874
# chol        0.081437
# fbs         0.026826
# Name: target, dtype: float64

# %% [markdown]
# # ***Explanatory Data Analysis***

# %% [markdown]
# # ***Analyzing "target" Feature***

# %%
sns.countplot(x = "target", data = df)

target_temp = df.target.value_counts()

print(target_temp)
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
print("Percentage of patience without heart problems: "+str(round(target_temp[0]*100/302,2)))
print("Percentage of patience with heart problems: "+str(round(target_temp[1]*100/302,2)))
# Out:
# Percentage of patience without heart problems: 45.7
# Percentage of patience with heart problems: 54.3

# %% [markdown]
# # ***Analyzing "Sex" Feature***

# %%
df["sex"].unique()
# Out:
# array([1, 0])

# %%
sns.barplot(x = "sex", y = "target", data = df)
# Out:
# <Axes: xlabel='sex', ylabel='target'>

# %% [markdown]
# # ***Analyzing "cp" Feature***

# %%
df["cp"].unique()
# Out:
# array([0, 1, 2, 3])

# %%
sns.barplot(x = "cp", y = "target", data = df)
# Out:
# <Axes: xlabel='cp', ylabel='target'>

# %% [markdown]
# # ***Analyzing "fbs" Feature***

# %%
df["fbs"].describe()
# Out:
# count    302.000000
# mean       0.149007
# std        0.356686
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: fbs, dtype: float64

# %%
df["fbs"].unique()
# Out:
# array([0, 1])

# %%
sns.barplot(x = "fbs", y = "target", data = df)
# Out:
# <Axes: xlabel='fbs', ylabel='target'>

# %% [markdown]
# # ***Analyzing "restecg" Feature***

# %%
df["restecg"].unique()
# Out:
# array([1, 0, 2])

# %%
sns.barplot(x = "restecg",y = "target", data = df)
# Out:
# <Axes: xlabel='restecg', ylabel='target'>

# %% [markdown]
# # ***Analyzing "exang" Feature***

# %%
df["exang"].unique()
# Out:
# array([0, 1])

# %%
sns.barplot(x = "exang",y = "target", data = df)
# Out:
# <Axes: xlabel='exang', ylabel='target'>

# %% [markdown]
# # ***Analyzing "slope" Feature***

# %%
df["slope"].unique()
# Out:
# array([2, 0, 1])

# %%
sns.barplot(x = "slope",y = "target", data = df)
# Out:
# <Axes: xlabel='slope', ylabel='target'>

# %% [markdown]
# # ***Analyzing "ca" Feature***

# %%
df["ca"].unique()
# Out:
# array([2, 0, 1, 3, 4])

# %%
sns.countplot(x = "ca", data = df)
# Out:
# <Axes: xlabel='ca', ylabel='count'>

# %%
sns.barplot(x = "ca",y = "target", data = df)
# Out:
# <Axes: xlabel='ca', ylabel='target'>

# %% [markdown]
# # ***Analyzing "thal" Feature***

# %%
df["thal"].unique()
# Out:
# array([3, 2, 1, 0])

# %%
sns.barplot(x = "thal",y = "target", data = df)
# Out:
# <Axes: xlabel='thal', ylabel='target'>

# %%
sns.distplot(df["thal"])
# Out:
# <Axes: xlabel='thal', ylabel='Density'>

# %% [markdown]
# # ***Train-Test Split***

# %%
from sklearn.model_selection import train_test_split

predictors = df.drop("target",axis=1)
target = df["target"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (241, 13)

# %%
X_test.shape
# Out:
# (61, 13)

# %%
Y_train.shape
# Out:
# (241,)

# %%
Y_test.shape
# Out:
# (61,)

# %% [markdown]
# # ***Model Fitting***

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# # ***Logistic Regression***

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train,Y_train)

Y_pred_lr = lr.predict(X_test)

# %%
Y_pred_lr.shape
# Out:
# (61,)

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 83.61 %

# %% [markdown]
# # ***Navie Bayes***

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(X_train,Y_train)

Y_pred_nb = nb.predict(X_test)

# %%
Y_pred_nb.shape
# Out:
# (61,)

# %%
score_nb = round(accuracy_score(Y_pred_nb,Y_test)*100,2)

print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
# Out:
# The accuracy score achieved using Naive Bayes is: 80.33 %

# %% [markdown]
# # ***SVM***

# %%
from sklearn import svm

sv = svm.SVC(kernel='linear')

sv.fit(X_train, Y_train)

Y_pred_svm = sv.predict(X_test)

# %%
Y_pred_svm.shape
# Out:
# (61,)

# %%
score_svm = round(accuracy_score(Y_pred_svm,Y_test)*100,2)

print("The accuracy score achieved using Linear SVM is: "+str(score_svm)+" %")
# Out:
# The accuracy score achieved using Linear SVM is: 83.61 %

# %% [markdown]
# # ***KNN***

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,Y_train)
Y_pred_knn=knn.predict(X_test)

# %%
Y_pred_knn.shape
# Out:
# (61,)

# %%
score_knn = round(accuracy_score(Y_pred_knn,Y_test)*100,2)

print("The accuracy score achieved using KNN is: "+str(score_knn)+" %")
# Out:
# The accuracy score achieved using KNN is: 65.57 %

# %% [markdown]
# # ***Decision Tree***

# %%
from sklearn.tree import DecisionTreeClassifier

max_accuracy = 0


for x in range(200):
    dt = DecisionTreeClassifier(random_state=x)
    dt.fit(X_train,Y_train)
    Y_pred_dt = dt.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_dt,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        

dt = DecisionTreeClassifier(random_state=best_x)
dt.fit(X_train,Y_train)
Y_pred_dt = dt.predict(X_test)

# %%
print(Y_pred_dt.shape)
# Out:
# (61,)

# %%
score_dt = round(accuracy_score(Y_pred_dt,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 85.25 %

# %% [markdown]
# # ***Random Forest***

# %%
from sklearn.ensemble import RandomForestClassifier

max_accuracy = 0


for x in range(200):
    rf = RandomForestClassifier(random_state=x)
    rf.fit(X_train,Y_train)
    Y_pred_rf = rf.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_rf,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        

rf = RandomForestClassifier(random_state=best_x)
rf.fit(X_train,Y_train)
Y_pred_rf = rf.predict(X_test)

# %%
Y_pred_rf.shape
# Out:
# (61,)

# %%
score_rf = round(accuracy_score(Y_pred_rf,Y_test)*100,2)

print("The accuracy score achieved using Random Forest is: "+str(score_rf)+" %")
# Out:
# The accuracy score achieved using Random Forest is: 86.89 %

# %% [markdown]
# # ***XG Boost***

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train, Y_train)

Y_pred_xgb = xgb_model.predict(X_test)

# %%
Y_pred_xgb.shape
# Out:
# (61,)

# %%
score_xgb = round(accuracy_score(Y_pred_xgb,Y_test)*100,2)

print("The accuracy score achieved using XGBoost is: "+str(score_xgb)+" %")
# Out:
# The accuracy score achieved using XGBoost is: 78.69 %

# %% [markdown]
# # ***Neural Network***

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(11,activation='relu',input_dim=13))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X_train,Y_train,epochs=200)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 0s 3ms/step - loss: 82.9424 - accuracy: 0.5311
# Epoch 2/200
# 8/8 [==============================] - 0s 3ms/step - loss: 75.5063 - accuracy: 0.5311
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 68.9155 - accuracy: 0.5311
# Epoch 4/200
# 8/8 [==============================] - 0s 3ms/step - loss: 61.8891 - accuracy: 0.5311
# Epoch 5/200
# 8/8 [==============================] - 0s 2ms/step - loss: 55.2980 - accuracy: 0.5311
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 48.4942 - accuracy: 0.5311
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 41.6878 - accuracy: 0.5311
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 35.2225 - accuracy: 0.5311
# Epoch 9/200
# 8/8 [==============================] - 0s 2ms/step - loss: 28.1725 - accuracy: 0.5311
# Epoch 10/200
# 8/8 [==============================] - 0s 2ms/step - loss: 21.5546 - accuracy: 0.5311
# Epoch 11/200
# 8/8 [==============================] - 0s 2ms/step - loss: 14.8040 - accuracy: 0.5353
# Epoch 12/200
# 8/8 [==============================] - 0s 1ms/step - loss: 7.9520 - accuracy: 0.5477
# Epoch 13/200
# 8/8 [==============================] - 0s 2ms/step - loss: 3.0086 - accuracy: 0.6224
# Epoch 14/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.5049 - accuracy: 0.5975
# Epoch 15/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.5480 - accuracy: 0.6058
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0664 - accuracy: 0.6515
# Epoch 17/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0836 - accuracy: 0.6639
# Epoch 18/200
# 8/8 [==============================] - 0s 2ms/step - loss: 2.0449 - accuracy: 0.6680
# Epoch 19/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.9937 - accuracy: 0.6515
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9799 - accuracy: 0.6556
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9610 - accuracy: 0.6556
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9383 - accuracy: 0.6556
# Epoch 23/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.9250 - accuracy: 0.6515
# Epoch 24/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8983 - accuracy: 0.6598
# Epoch 25/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.9101 - accuracy: 0.6556
# Epoch 26/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8711 - accuracy: 0.6473
# Epoch 27/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8581 - accuracy: 0.6556
# Epoch 28/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.8361 - accuracy: 0.6556
# Epoch 29/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.8205 - accuracy: 0.6556
# Epoch 30/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8028 - accuracy: 0.6515
# Epoch 31/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.7867 - accuracy: 0.6473
# Epoch 32/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.7749 - accuracy: 0.6556
# Epoch 33/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.7589 - accuracy: 0.6598
# Epoch 34/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7264 - accuracy: 0.6432
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7398 - accuracy: 0.6639
# Epoch 36/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.7134 - accuracy: 0.6639
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6801 - accuracy: 0.6598
# Epoch 38/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.6749 - accuracy: 0.6639
# Epoch 39/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.6583 - accuracy: 0.6639
# Epoch 40/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6350 - accuracy: 0.6598
# Epoch 41/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.6193 - accuracy: 0.6556
# Epoch 42/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6013 - accuracy: 0.6598
# Epoch 43/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5865 - accuracy: 0.6598
# Epoch 44/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5705 - accuracy: 0.6598
# Epoch 45/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5491 - accuracy: 0.6639
# Epoch 46/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5381 - accuracy: 0.6680
# Epoch 47/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5183 - accuracy: 0.6598
# Epoch 48/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5079 - accuracy: 0.6639
# Epoch 49/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4841 - accuracy: 0.6598
# Epoch 50/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4834 - accuracy: 0.6639
# Epoch 51/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.4533 - accuracy: 0.6598
# Epoch 52/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4472 - accuracy: 0.6680
# Epoch 53/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4193 - accuracy: 0.6639
# Epoch 54/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4090 - accuracy: 0.6763
# Epoch 55/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3847 - accuracy: 0.6763
# Epoch 56/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3701 - accuracy: 0.6639
# Epoch 57/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3554 - accuracy: 0.6763
# Epoch 58/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3388 - accuracy: 0.6680
# Epoch 59/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.3170 - accuracy: 0.6722
# Epoch 60/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3071 - accuracy: 0.6888
# Epoch 61/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2905 - accuracy: 0.6722
# Epoch 62/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.2701 - accuracy: 0.6763
# Epoch 63/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2614 - accuracy: 0.6805
# Epoch 64/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2511 - accuracy: 0.6846
# Epoch 65/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2302 - accuracy: 0.6805
# Epoch 66/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.2098 - accuracy: 0.6846
# Epoch 67/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.2039 - accuracy: 0.6763
# Epoch 68/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1808 - accuracy: 0.6805
# Epoch 69/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1630 - accuracy: 0.6763
# Epoch 70/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1467 - accuracy: 0.6805
# Epoch 71/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.1368 - accuracy: 0.6846
# Epoch 72/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1281 - accuracy: 0.6888
# Epoch 73/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1110 - accuracy: 0.6805
# Epoch 74/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0946 - accuracy: 0.6846
# Epoch 75/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0759 - accuracy: 0.6805
# Epoch 76/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0648 - accuracy: 0.6805
# Epoch 77/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0585 - accuracy: 0.6805
# Epoch 78/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0381 - accuracy: 0.6722
# Epoch 79/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.0470 - accuracy: 0.6929
# Epoch 80/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0406 - accuracy: 0.6722
# Epoch 81/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9931 - accuracy: 0.6929
# Epoch 82/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0039 - accuracy: 0.6763
# Epoch 83/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9735 - accuracy: 0.6805
# Epoch 84/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9544 - accuracy: 0.6888
# Epoch 85/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9403 - accuracy: 0.6846
# Epoch 86/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9329 - accuracy: 0.6888
# Epoch 87/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9178 - accuracy: 0.6805
# Epoch 88/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9172 - accuracy: 0.7095
# Epoch 89/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.9344 - accuracy: 0.6639
# Epoch 90/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8987 - accuracy: 0.6888
# Epoch 91/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8752 - accuracy: 0.6846
# Epoch 92/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8854 - accuracy: 0.6846
# Epoch 93/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8503 - accuracy: 0.6929
# Epoch 94/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8501 - accuracy: 0.7054
# Epoch 95/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8239 - accuracy: 0.7054
# Epoch 96/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8624 - accuracy: 0.6722
# Epoch 97/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8047 - accuracy: 0.7137
# Epoch 98/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8022 - accuracy: 0.7137
# Epoch 99/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7903 - accuracy: 0.6888
# Epoch 100/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7744 - accuracy: 0.7054
# Epoch 101/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7692 - accuracy: 0.7054
# Epoch 102/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7631 - accuracy: 0.7095
# Epoch 103/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7604 - accuracy: 0.7137
# Epoch 104/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7562 - accuracy: 0.7303
# Epoch 105/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7676 - accuracy: 0.6888
# Epoch 106/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7364 - accuracy: 0.7344
# Epoch 107/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.7052 - accuracy: 0.7344
# Epoch 108/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7142 - accuracy: 0.6971
# Epoch 109/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6996 - accuracy: 0.7220
# Epoch 110/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6890 - accuracy: 0.7261
# Epoch 111/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6800 - accuracy: 0.7220
# Epoch 112/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6733 - accuracy: 0.7261
# Epoch 113/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6638 - accuracy: 0.7303
# Epoch 114/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6591 - accuracy: 0.7054
# Epoch 115/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6511 - accuracy: 0.7427
# Epoch 116/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6526 - accuracy: 0.7137
# Epoch 117/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6496 - accuracy: 0.7427
# Epoch 118/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6272 - accuracy: 0.7220
# Epoch 119/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6204 - accuracy: 0.7261
# Epoch 120/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6280 - accuracy: 0.7593
# Epoch 121/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6135 - accuracy: 0.7178
# Epoch 122/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6168 - accuracy: 0.7510
# Epoch 123/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6206 - accuracy: 0.7012
# Epoch 124/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5911 - accuracy: 0.7593
# Epoch 125/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5853 - accuracy: 0.7552
# Epoch 126/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5818 - accuracy: 0.7344
# Epoch 127/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5806 - accuracy: 0.7593
# Epoch 128/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5743 - accuracy: 0.7469
# Epoch 129/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5850 - accuracy: 0.7261
# Epoch 130/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5580 - accuracy: 0.7593
# Epoch 131/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5641 - accuracy: 0.7344
# Epoch 132/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5626 - accuracy: 0.7593
# Epoch 133/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5614 - accuracy: 0.7178
# Epoch 134/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5408 - accuracy: 0.7593
# Epoch 135/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5366 - accuracy: 0.7759
# Epoch 136/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5409 - accuracy: 0.7593
# Epoch 137/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5503 - accuracy: 0.7220
# Epoch 138/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5243 - accuracy: 0.7718
# Epoch 139/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5204 - accuracy: 0.7759
# Epoch 140/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5181 - accuracy: 0.7801
# Epoch 141/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5690 - accuracy: 0.7718
# Epoch 142/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5459 - accuracy: 0.7386
# Epoch 143/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5245 - accuracy: 0.7552
# Epoch 144/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5081 - accuracy: 0.7759
# Epoch 145/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4970 - accuracy: 0.7884
# Epoch 146/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4939 - accuracy: 0.7884
# Epoch 147/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4893 - accuracy: 0.7925
# Epoch 148/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4873 - accuracy: 0.7842
# Epoch 149/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4828 - accuracy: 0.7842
# Epoch 150/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5098 - accuracy: 0.7510
# Epoch 151/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4885 - accuracy: 0.7842
# Epoch 152/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4727 - accuracy: 0.8008
# Epoch 153/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4746 - accuracy: 0.8008
# Epoch 154/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4788 - accuracy: 0.7967
# Epoch 155/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4828 - accuracy: 0.7884
# Epoch 156/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4704 - accuracy: 0.7925
# Epoch 157/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4732 - accuracy: 0.7884
# Epoch 158/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4583 - accuracy: 0.7925
# Epoch 159/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4602 - accuracy: 0.7925
# Epoch 160/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4707 - accuracy: 0.8008
# Epoch 161/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4525 - accuracy: 0.7967
# Epoch 162/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4551 - accuracy: 0.8008
# Epoch 163/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4657 - accuracy: 0.7801
# Epoch 164/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4609 - accuracy: 0.7925
# Epoch 165/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4592 - accuracy: 0.7884
# Epoch 166/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4448 - accuracy: 0.8008
# Epoch 167/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4428 - accuracy: 0.8050
# Epoch 168/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4387 - accuracy: 0.8050
# Epoch 169/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4377 - accuracy: 0.8008
# Epoch 170/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4431 - accuracy: 0.8050
# Epoch 171/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4390 - accuracy: 0.7967
# Epoch 172/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4330 - accuracy: 0.8008
# Epoch 173/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4305 - accuracy: 0.8133
# Epoch 174/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4297 - accuracy: 0.7925
# Epoch 175/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4274 - accuracy: 0.8008
# Epoch 176/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4376 - accuracy: 0.8008
# Epoch 177/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4357 - accuracy: 0.8174
# Epoch 178/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4219 - accuracy: 0.8008
# Epoch 179/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4214 - accuracy: 0.8050
# Epoch 180/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4236 - accuracy: 0.7967
# Epoch 181/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4412 - accuracy: 0.8008
# Epoch 182/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4342 - accuracy: 0.8174
# Epoch 183/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4272 - accuracy: 0.8133
# Epoch 184/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4165 - accuracy: 0.8050
# Epoch 185/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4164 - accuracy: 0.8050
# Epoch 186/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4217 - accuracy: 0.8050
# Epoch 187/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4163 - accuracy: 0.8174
# Epoch 188/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4278 - accuracy: 0.8174
# Epoch 189/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4150 - accuracy: 0.8050
# Epoch 190/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4096 - accuracy: 0.8133
# Epoch 191/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4141 - accuracy: 0.8216
# Epoch 192/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4140 - accuracy: 0.8091
# Epoch 193/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4107 - accuracy: 0.8216
# Epoch 194/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4052 - accuracy: 0.8133
# Epoch 195/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4081 - accuracy: 0.8091
# Epoch 196/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4114 - accuracy: 0.8216
# Epoch 197/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4072 - accuracy: 0.8216
# Epoch 198/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4131 - accuracy: 0.8257
# Epoch 199/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4019 - accuracy: 0.8091
# Epoch 200/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4066 - accuracy: 0.8257

# %%
Y_pred_nn = model.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
Y_pred_nn.shape
# Out:
# (61, 1)

# %%
rounded = [round(x[0]) for x in Y_pred_nn]

Y_pred_nn = rounded

# %%
score_nn = round(accuracy_score(Y_pred_nn,Y_test)*100,2)

print("The accuracy score achieved using Neural Network is: "+str(score_nn)+" %")
# Out:
# The accuracy score achieved using Neural Network is: 83.61 %

# %% [markdown]
# # ***Output Final Scores***

# %%
scores = [score_lr,score_nb,score_svm,score_knn,score_dt,score_rf,score_xgb,score_nn]
algorithms = ["Logistic Regression","Naive Bayes","Support Vector Machine","K-Nearest Neighbors","Decision Tree","Random Forest","XGBoost","Neural Network"]    

for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 83.61 %
# The accuracy score achieved using Naive Bayes is: 80.33 %
# The accuracy score achieved using Support Vector Machine is: 83.61 %
# The accuracy score achieved using K-Nearest Neighbors is: 65.57 %
# The accuracy score achieved using Decision Tree is: 85.25 %
# The accuracy score achieved using Random Forest is: 86.89 %
# The accuracy score achieved using XGBoost is: 78.69 %
# The accuracy score achieved using Neural Network is: 83.61 %

# %% [markdown]
# # ***Plotting the Results***

# %%
sns.set(rc={'figure.figsize':(20,10)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")

sns.barplot(x = algorithms,y = scores)
# Out:
# <Axes: xlabel='Algorithms', ylabel='Accuracy score'>

# %% [markdown]
# # ***Therefore, we can conclude that Random Forest Algorithm has the better accuracy for our model than other algorithms.                                                                                        The algorithms from best accuracy to least are Random Forest, Decision Tree, Logistic Regression, Support Vector Machine(SVM), Neural Network, Naive Bayes, XGBoost, K-Nearest Neighbors(KNN)***
